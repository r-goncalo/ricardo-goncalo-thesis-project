# %%
from automl.utils.class_util import make_classes_in_collection_strings

from automl.base_configurations.environment.cart_pole.ppo_sb3 import config_dict as base_config_dict



non_str_base_config_dict = base_config_dict()

str_base_config_dict = make_classes_in_collection_strings(non_str_base_config_dict)

# %%
print(str_base_config_dict)
# Out:
# {'__type__': "<class 'automl.rl.rl_pipeline.RLPipelineComponent'>", 'name': 'RLPipelineComponent', 'input': {'device': 'cuda', 'environment': ("<class 'automl.rl.environment.gymnasium_env.GymnasiumEnvironmentWrapper'>", {'environment': 'CartPole-v1'}), 'agents_input': {'policy': ("<class 'automl.rl.policy.stochastic_policy.StochasticPolicy'>", {'model': ("<class 'automl.ml.models.neural_model.FullyConnectedModelSchema'>", {'hidden_layers': 3, 'hidden_size': 64})})}, 'rl_trainer': ("<class 'automl.rl.trainers.rl_trainer_component.RLTrainerComponent'>", {'name': 'RLTrainerComponent', 'default_trainer_class': "<class 'automl.rl.trainers.agent_trainer_ppo.AgentTrainerPPO'>", 'limit_total_steps': 100000.0, 'optimization_interval': 256, 'predict_optimizations_to_do': True, 'agents_trainers_input': {'learner': ("<class 'automl.rl.learners.ppo_learner.PPOLearner'>", {'lamda_gae': 0.8, 'critic_model': ("<class 'automl.ml.models.neural_model.FullyConnectedModelSchema'>", {'hidden_layers': 2, 'hidden_size': 64}), 'optimizer': ("<class 'automl.ml.optimizers.optimizer_components.AdamOptimizer'>", {'name': 'AdamOpimizerComponent', 'learning_rate': 0.0023, 'linear_decay_learning_rate_with_final_input_value_of': ('relative', [('__get_by_name__', {'name_of_component': 'RLTrainerComponent'}), ('__get_exposed_value__', {'value_localization': ['optimizations_to_do_per_agent', 'agent']})]), 'clip_grad_value': ("<class 'automl.basic_components.dynamic_value.DynamicLinearValueInRangeBasedOnComponent'>", {'input_for_fun_key': 'optimizations_done', 'initial_value': 0.2, 'final_value': 0, 'input_component': ('relative', ('__get_by_name__', {'name_of_component': 'AdamOpimizerComponent'})), 'input_for_fun_max_value': ('relative', [('__get_by_name__', {'name_of_component': 'RLTrainerComponent'}), ('__get_exposed_value__', {'value_localization': ['optimizations_to_do_per_agent', 'agent']})])})})}), 'discount_factor': 0.98, 'optimization_interval': 256, 'times_to_learn': 20, 'memory': ("<class 'automl.ml.memory.torch_memory_component.TorchMemoryComponent'>", {'capacity': 256})}})}}

# %%
import json


print(json.dumps(str_base_config_dict, indent=4))
# Out:
# {'__type__': "<class 'automl.rl.rl_pipeline.RLPipelineComponent'>",
#  'input': {'agents_input': {'policy': ('<class '
#                                        "'automl.rl.policy.stochastic_policy.StochasticPolicy'>",
#                                        {'model': ('<class '
#                                                   "'automl.ml.models.neural_model.FullyConnectedModelSchema'>",
#                                                   {'hidden_layers': 3,
#                                                    'hidden_size': 64})})},
#            'device': 'cuda',
#            'environment': ('<class '
#                            "'automl.rl.environment.gymnasium_env.GymnasiumEnvironmentWrapper'>",
#                            {'environment': 'CartPole-v1'}),
#            'rl_trainer': ('<class '
#                           "'automl.rl.trainers.rl_trainer_component.RLTrainerComponent'>",
#                           {'agents_trainers_input': {'discount_factor': 0.98,
#                                                      'learner': ('<class '
#                                                                  "'automl.rl.learners.ppo_learner.PPOLearner'>",
#                                                                  {'critic_model': ('<class '
#                                                                                    "'automl.ml.models.neural_model.FullyConnectedModelSchema'>",
#                                                                                    {'hidden_layers': 2,
#                                                                                     'hidden_size': 64}),
#                                                                   'lamda_gae': 0.8,
#                                                                   'optimizer': ('<class '
#                                                                                 "'automl.ml.optimizers.optimizer_components.AdamOptimizer'>",
#                                                                                 {'clip_grad_value': ('<class '
#                                                                                                      "'automl.basic_components.dynamic_value.DynamicLinearValueInRangeBasedOnComponent'>",
#                                                                                                      {'final_value': 0,
#                                                                                                       'initial_value': 0.2,
#                                                                                                       'input_component': ('relative',
#                                                                                                                           ('__get_by_name__',
#                                                                                                                            {'name_of_component': 'AdamOpimizerComponent'})),
#                                                                                                       'input_for_fun_key': 'optimizations_done',
#                                                                                                       'input_for_fun_max_value': ('relative',
#                                                                                                                                   [('__get_by_name__',
#                                                                                                                                     {'name_of_component': 'RLTrainerComponent'}),
#                                                                                                                                    ('__get_exposed_value__',
#                                                                                                                                     {'value_localization': ['optimizations_to_do_per_agent',
#                                                                                                                                                             'agent']})])}),
#                                                                                  'learning_rate': 0.0023,
#                                                                                  'linear_decay_learning_rate_with_final_input_value_of': ('relative',
#                                                                                                                                           [('__get_by_name__',
#                                                                                                                                             {'name_of_component': 'RLTrainerComponent'}),
#                                                                                                                                            ('__get_exposed_value__',
#                                                                                                                                             {'value_localization': ['optimizations_to_do_per_agent',
#                                                                                                                                                                     'agent']})]),
#                                                                                  'name': 'AdamOpimizerComponent'})}),
#                                                      'memory': ('<class '
#                                                                 "'automl.ml.memory.torch_memory_component.TorchMemoryComponent'>",
#                                                                 {'capacity': 256}),
#                                                      'optimization_interval': 256,
#                                                      'times_to_learn': 20},
#                            'default_trainer_class': '<class '
#                                                     "'automl.rl.trainers.agent_trainer_ppo.AgentTrainerPPO'>",
#                            'limit_total_steps': 100000.0,
#                            'name': 'RLTrainerComponent',
#                            'optimization_interval': 256,
#                            'predict_optimizations_to_do': True})},
#  'name': 'RLPipelineComponent'}
