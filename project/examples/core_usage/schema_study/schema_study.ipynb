# %% [markdown]
# # Schemas

# %% [markdown]
# Schemas are the classes for our components
#
# Besides normal functionality of classes, they also have some other attributes

# %%
#from automl.component import Component as schema_to_study
#from automl.rl.trainers.agent_trainer_component_dqn import AgentTrainerDQN as schema_to_study
from automl.rl.rl_pipeline import RLPipelineComponent as schema_to_study

# %% [markdown]
# ## Schema Type

# %% [markdown]
# ## Schema name

# %%
print(schema_to_study)
# Out:
# <class 'automl.rl.rl_pipeline.RLPipelineComponent'>

# %% [markdown]
# ## Schema parameter signature

# %% [markdown]
# One thing to notice in a parameter signature is that there is no repeated keys
#
# If a class defines the parameter signature a superclasses has already defined, they "fuse"
#
# The class inherits the Parameter Signatures of their superclasses

# %%
from automl.core.input_management import InputSignature


schema_parameter_signature : dict[str, InputSignature]= schema_to_study.parameters_signature

parameter_signature_to_print = {}

for key, value in schema_parameter_signature.items():

    parameter_signature_to_print[key] = value.to_dict()

# %%
import json


print(json.dumps(parameter_signature_to_print, indent=4))
# Out:
# {
#     "device": {
#         "get_from_parent": "False",
#         "default_value": "cuda",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "True",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "environment": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "<function ComponentInputSignature.__init__.<locals>.generator at 0x000001FAADE0D800>",
#         "validity_verificator": "[]",
#         "possible_types": "[<class 'automl.component.Component'>, <class 'type'>, <class 'dict'>, <class 'str'>, <class 'tuple'>, <class 'list'>, <class 'automl.rl.environment.environment_components.EnvironmentComponent'>]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True",
#         "default_component_definition": "(<class 'automl.rl.environment.pettingzoo_env.PettingZooEnvironmentWrapper'>, {})"
#     },
#     "agents": {
#         "get_from_parent": "False",
#         "default_value": "{}",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "agents_input": {
#         "get_from_parent": "False",
#         "default_value": "{}",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "True",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "save_in_between": {
#         "get_from_parent": "False",
#         "default_value": "True",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "rl_trainer": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "<function ComponentInputSignature.__init__.<locals>.generator at 0x000001FAADE0DA80>",
#         "validity_verificator": "[]",
#         "possible_types": "[<class 'automl.component.Component'>, <class 'type'>, <class 'dict'>, <class 'str'>, <class 'tuple'>, <class 'list'>]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True",
#         "default_component_definition": "(<class 'automl.rl.trainers.rl_trainer_component.RLTrainerComponent'>, {})"
#     },
#     "fraction_of_training_to_do_in_session": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "If when this is run it is supposed to do only a fraction of the training, this affects the stop condition",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "False"
#     },
#     "generate_fraction_from_times_to_run": {
#         "get_from_parent": "False",
#         "default_value": "False",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "times_to_run": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "The number of times to run the component",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "False"
#     },
#     "save_state_on_run_end": {
#         "get_from_parent": "False",
#         "default_value": "True",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "True",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "save_dataframes_on_run_end": {
#         "get_from_parent": "False",
#         "default_value": "True",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "True",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "name": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "True",
#         "priority": "0",
#         "on_pass": "[<function on_name_pass at 0x000001FA8044FA60>]",
#         "mandatory": "False"
#     },
#     "logger_object": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "<function generate_logger_for_component at 0x000001FA804994E0>",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "True",
#         "priority": "10",
#         "on_pass": "[<function on_log_pass at 0x000001FA80499440>]",
#         "mandatory": "True"
#     },
#     "logger_input": {
#         "get_from_parent": "False",
#         "default_value": "{}",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "True",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "create_new_directory": {
#         "get_from_parent": "False",
#         "default_value": "True",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "If it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent",
#         "ignore_at_serialization": "True",
#         "priority": "1",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "artifact_relative_directory": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "<function ArtifactComponent.<lambda> at 0x000001FA80477E20>",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "2",
#         "on_pass": "[<function on_artifact_directory_change at 0x000001FA80477A60>]",
#         "mandatory": "True"
#     },
#     "base_directory": {
#         "get_from_parent": "False",
#         "default_value": "",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "This path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component",
#         "ignore_at_serialization": "True",
#         "priority": "2",
#         "on_pass": "[<function on_artifact_directory_change at 0x000001FA80477A60>]",
#         "mandatory": "True"
#     },
#     "results_logger_object": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "<function generate_logger_for_component at 0x000001FA8049A520>",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "A dictionary of result loggers object or single one",
#         "ignore_at_serialization": "True",
#         "priority": "10",
#         "on_pass": "[<function on_log_pass at 0x000001FA8049A340>]",
#         "mandatory": "True"
#     },
#     "component_evaluator": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[<class 'automl.component.Component'>, <class 'type'>, <class 'dict'>, <class 'str'>, <class 'tuple'>, <class 'list'>]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "False",
#         "default_component_definition": "None"
#     },
#     "seed": {
#         "get_from_parent": "False",
#         "default_value": "None",
#         "generator": "<function SeededComponent.<lambda> at 0x000001FAADC45B20>",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "None",
#         "ignore_at_serialization": "False",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     },
#     "do_full_setup_of_seed": {
#         "get_from_parent": "False",
#         "default_value": "False",
#         "generator": "None",
#         "validity_verificator": "[]",
#         "possible_types": "[]",
#         "description": "If it is supposed to setup the seed for things like torch, python, and so on",
#         "ignore_at_serialization": "True",
#         "priority": "50",
#         "on_pass": "[]",
#         "mandatory": "True"
#     }
# }

# %% [markdown]
# ### Priorities

# %% [markdown]
# Schemas have priorities, which define the ordered they are processed

# %%
parameter_signature_ordered_priorities : list[int] = schema_to_study.parameters_signature_priorities

print(parameter_signature_ordered_priorities)
# Out:
# [0, 1, 2, 10, 50]

# %%
# This is to look at priorities in a printable format

parameter_signature_by_priorities = schema_to_study.organized_parameters_signatures

print(parameter_signature_by_priorities)


parameter_signature_by_priorities_to_print : dict[int, dict[str, InputSignature]]  = {}

for priority in parameter_signature_ordered_priorities:

    to_print_of_priority : dict[str, dict] = {}

    parameter_signature_by_priorities_to_print[priority] = to_print_of_priority

    parameter_signatures_of_priority : dict[str, InputSignature] = parameter_signature_by_priorities[priority]

    for key, value in parameter_signatures_of_priority.items():

        to_print_of_priority[key] = value.to_dict()
# Out:
# {50: {'device': <automl.core.input_management.InputSignature object at 0x000001FAADDED6D0>, 'environment': <automl.core.advanced_input_management.ComponentInputSignature object at 0x000001FAADD8D150>, 'agents': <automl.core.input_management.InputSignature object at 0x000001FAADE0D8B0>, 'agents_input': <automl.core.input_management.InputSignature object at 0x000001FAADE0D950>, 'save_in_between': <automl.core.input_management.InputSignature object at 0x000001FAADE0D9F0>, 'rl_trainer': <automl.core.advanced_input_management.ComponentInputSignature object at 0x000001FAADD41310>, 'fraction_of_training_to_do_in_session': <automl.core.input_management.InputSignature object at 0x000001FAADE0DB30>, 'generate_fraction_from_times_to_run': <automl.core.input_management.InputSignature object at 0x000001FAADE0DBD0>, 'times_to_run': <automl.core.input_management.InputSignature object at 0x000001FAADB7E210>, 'save_state_on_run_end': <automl.core.input_management.InputSignature object at 0x000001FAADC45130>, 'save_dataframes_on_run_end': <automl.core.input_management.InputSignature object at 0x000001FAADC451D0>, 'logger_input': <automl.core.input_management.InputSignature object at 0x000001FA80446A50>, 'component_evaluator': <automl.core.advanced_input_management.ComponentInputSignature object at 0x000001FA804A0050>, 'seed': <automl.core.input_management.InputSignature object at 0x000001FAADC46030>, 'do_full_setup_of_seed': <automl.core.input_management.InputSignature object at 0x000001FAADC460D0>}, 0: {'name': <automl.core.input_management.InputSignature object at 0x000001FAADE0EA30>}, 10: {'logger_object': <automl.core.input_management.InputSignature object at 0x000001FA80446B30>, 'results_logger_object': <automl.core.input_management.InputSignature object at 0x000001FAA29A97B0>}, 1: {'create_new_directory': <automl.core.input_management.InputSignature object at 0x000001FAADE0E7B0>}, 2: {'artifact_relative_directory': <automl.core.input_management.InputSignature object at 0x000001FAADE0E8F0>, 'base_directory': <automl.core.input_management.InputSignature object at 0x000001FAADE0E990>}}

# %%
print(json.dumps(parameter_signature_by_priorities_to_print, indent=4))
# Out:
# {
#     "0": {
#         "name": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "True",
#             "priority": "0",
#             "on_pass": "[<function on_name_pass at 0x000001FA8044FA60>]",
#             "mandatory": "False"
#         }
#     },
#     "1": {
#         "create_new_directory": {
#             "get_from_parent": "False",
#             "default_value": "True",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "If it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent\nIf it is supposed to create a new directory if existent",
#             "ignore_at_serialization": "True",
#             "priority": "1",
#             "on_pass": "[]",
#             "mandatory": "True"
#         }
#     },
#     "2": {
#         "artifact_relative_directory": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "<function ArtifactComponent.<lambda> at 0x000001FA80477E20>",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "2",
#             "on_pass": "[<function on_artifact_directory_change at 0x000001FA80477A60>]",
#             "mandatory": "True"
#         },
#         "base_directory": {
#             "get_from_parent": "False",
#             "default_value": "",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "This path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component\nThis path is used as basis to calculate the artifact directory of a component",
#             "ignore_at_serialization": "True",
#             "priority": "2",
#             "on_pass": "[<function on_artifact_directory_change at 0x000001FA80477A60>]",
#             "mandatory": "True"
#         }
#     },
#     "10": {
#         "logger_object": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "<function generate_logger_for_component at 0x000001FA804994E0>",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "True",
#             "priority": "10",
#             "on_pass": "[<function on_log_pass at 0x000001FA80499440>]",
#             "mandatory": "True"
#         },
#         "results_logger_object": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "<function generate_logger_for_component at 0x000001FA8049A520>",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "A dictionary of result loggers object or single one",
#             "ignore_at_serialization": "True",
#             "priority": "10",
#             "on_pass": "[<function on_log_pass at 0x000001FA8049A340>]",
#             "mandatory": "True"
#         }
#     },
#     "50": {
#         "device": {
#             "get_from_parent": "False",
#             "default_value": "cuda",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "True",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "environment": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "<function ComponentInputSignature.__init__.<locals>.generator at 0x000001FAADE0D800>",
#             "validity_verificator": "[]",
#             "possible_types": "[<class 'automl.component.Component'>, <class 'type'>, <class 'dict'>, <class 'str'>, <class 'tuple'>, <class 'list'>, <class 'automl.rl.environment.environment_components.EnvironmentComponent'>]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True",
#             "default_component_definition": "(<class 'automl.rl.environment.pettingzoo_env.PettingZooEnvironmentWrapper'>, {})"
#         },
#         "agents": {
#             "get_from_parent": "False",
#             "default_value": "{}",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "agents_input": {
#             "get_from_parent": "False",
#             "default_value": "{}",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "True",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "save_in_between": {
#             "get_from_parent": "False",
#             "default_value": "True",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "rl_trainer": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "<function ComponentInputSignature.__init__.<locals>.generator at 0x000001FAADE0DA80>",
#             "validity_verificator": "[]",
#             "possible_types": "[<class 'automl.component.Component'>, <class 'type'>, <class 'dict'>, <class 'str'>, <class 'tuple'>, <class 'list'>]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True",
#             "default_component_definition": "(<class 'automl.rl.trainers.rl_trainer_component.RLTrainerComponent'>, {})"
#         },
#         "fraction_of_training_to_do_in_session": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "If when this is run it is supposed to do only a fraction of the training, this affects the stop condition",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "False"
#         },
#         "generate_fraction_from_times_to_run": {
#             "get_from_parent": "False",
#             "default_value": "False",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "times_to_run": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "The number of times to run the component",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "False"
#         },
#         "save_state_on_run_end": {
#             "get_from_parent": "False",
#             "default_value": "True",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "True",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "save_dataframes_on_run_end": {
#             "get_from_parent": "False",
#             "default_value": "True",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "True",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "logger_input": {
#             "get_from_parent": "False",
#             "default_value": "{}",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "True",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "component_evaluator": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[<class 'automl.component.Component'>, <class 'type'>, <class 'dict'>, <class 'str'>, <class 'tuple'>, <class 'list'>]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "False",
#             "default_component_definition": "None"
#         },
#         "seed": {
#             "get_from_parent": "False",
#             "default_value": "None",
#             "generator": "<function SeededComponent.<lambda> at 0x000001FAADC45B20>",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "None",
#             "ignore_at_serialization": "False",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         },
#         "do_full_setup_of_seed": {
#             "get_from_parent": "False",
#             "default_value": "False",
#             "generator": "None",
#             "validity_verificator": "[]",
#             "possible_types": "[]",
#             "description": "If it is supposed to setup the seed for things like torch, python, and so on",
#             "ignore_at_serialization": "True",
#             "priority": "50",
#             "on_pass": "[]",
#             "mandatory": "True"
#         }
#     }
# }

# %% [markdown]
# ## Schema MRO

# %% [markdown]
# The MRO, Method Resolution Order, in python, shows the class of a type and its superclasses
#
# This is useful to remember when thinking about inheritance. For example, a class can only be inherited once.

# %%
print(schema_to_study.__mro__)
# Out:
# (<class 'automl.rl.rl_pipeline.RLPipelineComponent'>, <class 'automl.basic_components.exec_component.ExecComponent'>, <class 'automl.loggers.logger_component.ComponentWithLogging'>, <class 'automl.loggers.component_with_results.ComponentWithResults'>, <class 'automl.basic_components.state_management.StatefulComponent'>, <class 'automl.basic_components.artifact_management.ArtifactComponent'>, <class 'automl.basic_components.evaluator_component.ComponentWithEvaluator'>, <class 'automl.basic_components.seeded_component.SeededComponent'>, <class 'automl.component.Component'>, <class 'object'>)
