# %% [markdown]
# # Schemas

# %% [markdown]
# Schemas are the classes for our components
#
# Besides normal functionality of classes, they also have some other attributes

# %%
from automl.component import Component as Schema

# %% [markdown]
# ## Schema Type

# %%
print(Schema)
# Out:
# <class 'automl.component.Component'>
